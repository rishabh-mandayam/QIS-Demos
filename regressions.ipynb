# %%
import jax
import jax.numpy as jnp
import pandas as pd
from sklearn.impute import KNNImputer

# %% [markdown]
# ## EDA / Bare Minimum Feature Engineering

# %%
training_data = pd.read_csv ('data/train.csv')
training_data.describe
# Out:
# <bound method NDFrame.describe of         Id                                  industry             sector  \
# 0      196                         Personal Services  Consumer Cyclical
# 1     1568             Building Products & Equipment        Industrials
# 2     1218                                       NaN            Unknown
# 3       23        Scientific & Technical Instruments         Technology
# 4      783  Drug Manufacturers - Specialty & Generic         Healthcare
# ...    ...                                       ...                ...
# 1619  1916                Engineering & Construction        Industrials
# 1620  1162                             Biotechnology         Healthcare
# 1621   629                   Medical Care Facilities         Healthcare
# 1622  1841                             Biotechnology         Healthcare
# 1623  1179                         Resorts & Casinos  Consumer Cyclical
#
#       fullTimeEmployees  auditRisk  boardRisk  compensationRisk  \
# ...

# %%
training_data.dtypes
training_data.head(5)
# Out:
#      Id                                  industry             sector  \
# 0   196                         Personal Services  Consumer Cyclical
# 1  1568             Building Products & Equipment        Industrials
# 2  1218                                       NaN            Unknown
# 3    23        Scientific & Technical Instruments         Technology
# 4   783  Drug Manufacturers - Specialty & Generic         Healthcare
#
#    fullTimeEmployees  auditRisk  boardRisk  compensationRisk  \
# 0             1174.0        5.0       10.0               9.0
# 1             3600.0        4.0        4.0               3.0
# 2                NaN        NaN        NaN               NaN
# 3              143.0        NaN        NaN               NaN
# 4               36.0        NaN        NaN               NaN
#
#    shareHolderRightsRisk  overallRisk   trailingPE  ...  \
# 0                    4.0          8.0    12.549223  ...
# 1                    4.0          3.0  1222.000000  ...
# ...

# %%
training_data_dummies = pd.get_dummies(training_data, columns=['industry', 'sector'])
training_data_dummies.head(5)
# Out:
#      Id  fullTimeEmployees  auditRisk  boardRisk  compensationRisk  \
# 0   196             1174.0        5.0       10.0               9.0
# 1  1568             3600.0        4.0        4.0               3.0
# 2  1218                NaN        NaN        NaN               NaN
# 3    23              143.0        NaN        NaN               NaN
# 4   783               36.0        NaN        NaN               NaN
#
#    shareHolderRightsRisk  overallRisk   trailingPE  forwardPE  floatShares  \
# 0                    4.0          8.0    12.549223  10.530435   13278816.0
# 1                    4.0          3.0  1222.000000  13.730337   56524722.0
# 2                    NaN          NaN          NaN        NaN          NaN
# 3                    NaN          NaN          NaN  -1.226667    4951058.0
# 4                    NaN          NaN     1.231544   7.340000   33971093.0
#
#    ...  sector_Basic Materials  sector_Communication Services  \
# ...

# %%
##check nan count for each columns
nan_counts = training_data_dummies.isna().sum()
print(nan_counts)
# Out:
# Id                      0
# fullTimeEmployees      80
# auditRisk             493
# boardRisk             493
# compensationRisk      493
#                      ...
# sector_Healthcare       0
# sector_Industrials      0
# sector_Technology       0
# sector_Unknown          0
# sector_Utilities        0
# Length: 333, dtype: int64
